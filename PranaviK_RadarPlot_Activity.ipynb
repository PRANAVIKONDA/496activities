# %% [markdown]
# <a href="https://colab.research.google.com/github/PRANAVIKONDA/496activities/blob/main/PranaviK_RadarPlot_Activity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import math

AA=pd.DataFrame(columns=['criteria','weight','ratingA','scoreA','scoreB'])
print(AA)
# Out:
# Empty DataFrame
# Columns: [criteria, weight, ratingA, scoreA, scoreB]
# Index: []

# %%
AA['criteria']=['risk','ROI','customerSatisfaction','feasibility','strategicAlignment']
print(AA)
# Out:
#                criteria weight ratingA scoreA scoreB
# 0                  risk    NaN     NaN    NaN    NaN
# 1                   ROI    NaN     NaN    NaN    NaN
# 2  customerSatisfaction    NaN     NaN    NaN    NaN
# 3           feasibility    NaN     NaN    NaN    NaN
# 4    strategicAlignment    NaN     NaN    NaN    NaN

# %%
AA['weight']=[0.15,0.15,0.2,0.4,0.1]
print(AA)
# Out:
#                criteria  weight ratingA scoreA scoreB
# 0                  risk    0.15     NaN    NaN    NaN
# 1                   ROI    0.15     NaN    NaN    NaN
# 2  customerSatisfaction    0.20     NaN    NaN    NaN
# 3           feasibility    0.40     NaN    NaN    NaN
# 4    strategicAlignment    0.10     NaN    NaN    NaN

# %%
AA['ratingA']=[6,4,3,6,5]
AA['ratingB']=[2,3,4,6,7]
print(AA)
# Out:
#                criteria  weight  ratingA scoreA scoreB  ratingB
# 0                  risk    0.15        6    NaN    NaN        2
# 1                   ROI    0.15        4    NaN    NaN        3
# 2  customerSatisfaction    0.20        3    NaN    NaN        4
# 3           feasibility    0.40        6    NaN    NaN        6
# 4    strategicAlignment    0.10        5    NaN    NaN        7

# %%
for index, row in AA.iterrows():
  AA['scoreA'][index]=row['ratingB']*row['weight']
  AA['scoreB'][index]=row['ratingB']*row['weight']

print(AA)
# Out:
#                criteria  weight  ratingA scoreA scoreB  ratingB
# 0                  risk    0.15        6    0.3    0.3        2
# 1                   ROI    0.15        4   0.45   0.45        3
# 2  customerSatisfaction    0.20        3    0.8    0.8        4
# 3           feasibility    0.40        6    2.4    2.4        6
# 4    strategicAlignment    0.10        5    0.7    0.7        7
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
totalscoreA=0
totalscoreB=0
for index, row in AA.iterrows():
  totalscoreA+=row['scoreA']
  totalscoreB+=row['scoreB']
print ('the total score for A is {:.2f} and for B is {:.2f}'.format(totalscoreA, totalscoreB))
# Out:
# the total score for A is 4.65 and for B is 4.65

# %%
import numpy as np
import matplotlib.pyplot as plt

axisLocations = np.linspace(start=0, stop=2 * np.pi, num=len(AA['ratingA']), endpoint=False)
axisLocations = np.concatenate((axisLocations,[axisLocations[0]]))
ratingsA=AA['ratingA']
ratingsB=AA['ratingB']
ratingsACircular=np.concatenate((ratingsA,[ratingsA[0]]))
ratingsBCircular=np.concatenate((ratingsB,[ratingsB[0]]))

plt.figure(figsize=(10,10))
plt.subplot(polar=True)
plt.plot(axisLocations, ratingsACircular, 'o-', linewidth=2, label='In-house development')
plt.plot(axisLocations, ratingsBCircular,'d-', linewidth=2, label='Outsource')
plt.title('Project Options Comparision', size=20)
lines, labels =plt.thetagrids(np.degrees(axisLocations), labels=AA['criteria'])
plt.legend()
plt.show()
