# %% [markdown]
# <a href="https://colab.research.google.com/github/PRANAVIKONDA/496activities/blob/main/PranaviKonda_ASG05_DuPontAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd


myAPIKey = '08faf87f7d58fe68a394a20863fe8496'

stock = 'NFLX'

balanceStatements = requests.get(f'https://financialmodelingprep.com/api/v3/balance-sheet-statement/{stock}?apikey={myAPIKey}').json()

incomeStatements = requests.get(f'https://financialmodelingprep.com/api/v3/income-statement/{stock}?apikey={myAPIKey}').json()

print (balanceStatements[:5])
# Out:
# [{'date': '2021-12-31', 'symbol': 'NFLX', 'reportedCurrency': 'USD', 'cik': '0001065280', 'fillingDate': '2022-01-20', 'acceptedDate': '2022-01-27 17:03:33', 'calendarYear': '2021', 'period': 'FY', 'cashAndCashEquivalents': 6027804000, 'shortTermInvestments': 0.0, 'cashAndShortTermInvestments': 6027804000, 'netReceivables': 804320000, 'inventory': 0.0, 'otherCurrentAssets': 1237701000, 'totalCurrentAssets': 8069825000, 'propertyPlantEquipmentNet': 1323453000, 'goodwill': 0.0, 'intangibleAssets': 30919539000, 'goodwillAndIntangibleAssets': 30919539000, 'longTermInvestments': 0.0, 'taxAssets': 0.0, 'otherNonCurrentAssets': 4271846000, 'totalNonCurrentAssets': 36514838000, 'otherAssets': 0.0, 'totalAssets': 44584663000, 'accountPayables': 837483000, 'shortTermDebt': 699823000, 'taxPayables': 0.0, 'deferredRevenue': 1209342000, 'otherCurrentLiabilities': 5742318000, 'totalCurrentLiabilities': 8488966000, 'longTermDebt': 14693072000, 'deferredRevenueNonCurrent': 0.0, 'deferredTaxLiabilitiesNonCurrent': 0.0, 'otherNonCurrentLiabilities': 5553377000, 'totalNonCurrentLiabilities': 20246449000, 'otherLiabilities': 0.0, 'capitalLeaseObligations': 0, 'totalLiabilities': 28735415000, 'preferredStock': 0.0, 'commonStock': 4024561000, 'retainedEarnings': 12689372000, 'accumulatedOtherComprehensiveIncomeLoss': -40495000, 'othertotalStockholdersEquity': -824190000, 'totalStockholdersEquity': 15849248000, 'totalLiabilitiesAndStockholdersEquity': 44584663000, 'minorityInterest': 0, 'totalEquity': 15849248000, 'totalLiabilitiesAndTotalEquity': 44584663000, 'totalInvestments': 0.0, 'totalDebt': 15392895000, 'netDebt': 9365091000, 'link': 'https://www.sec.gov/Archives/edgar/data/1065280/000106528022000036/0001065280-22-000036-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/1065280/000106528022000036/nflx-20211231.htm'}, {'date': '2020-12-31', 'symbol': 'NFLX', 'reportedCurrency': 'USD', 'cik': '0001065280', 'fillingDate': '2021-01-28', 'acceptedDate': '2021-01-28 16:21:59', 'calendarYear': '2020', 'period': 'FY', 'cashAndCashEquivalents': 8205550000, 'shortTermInvestments': 0.0, 'cashAndShortTermInvestments': 8205550000, 'netReceivables': 610819000, 'inventory': 0.0, 'otherCurrentAssets': 945211000, 'totalCurrentAssets': 9761580000, 'propertyPlantEquipmentNet': 960183000, 'goodwill': 0.0, 'intangibleAssets': 25383950000, 'goodwillAndIntangibleAssets': 25383950000, 'longTermInvestments': 0.0, 'taxAssets': 0.0, 'otherNonCurrentAssets': 3174646000, 'totalNonCurrentAssets': 29518779000, 'otherAssets': 0.0, 'totalAssets': 39280359000, 'accountPayables': 656183000, 'shortTermDebt': 499878000, 'taxPayables': 0.0, 'deferredRevenue': 1117992000, 'otherCurrentLiabilities': 5531732000, 'totalCurrentLiabilities': 7805785000, 'longTermDebt': 15809095000, 'deferredRevenueNonCurrent': 0.0, 'deferredTaxLiabilitiesNonCurrent': 0.0, 'otherNonCurrentLiabilities': 4600239000, 'totalNonCurrentLiabilities': 20409334000, 'otherLiabilities': 0.0, 'capitalLeaseObligations': 0.0, 'totalLiabilities': 28215119000, 'preferredStock': 0.0, 'commonStock': 3447698000, 'retainedEarnings': 7573144000, 'accumulatedOtherComprehensiveIncomeLoss': 44398000, 'othertotalStockholdersEquity': 0.0, 'totalStockholdersEquity': 11065240000, 'totalLiabilitiesAndStockholdersEquity': 39280359000, 'minorityInterest': 0, 'totalEquity': 11065240000, 'totalLiabilitiesAndTotalEquity': 39280359000, 'totalInvestments': 0.0, 'totalDebt': 16308973000, 'netDebt': 8103423000, 'link': 'https://www.sec.gov/Archives/edgar/data/1065280/000106528021000040/0001065280-21-000040-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/1065280/000106528021000040/nflx-20201231.htm'}, {'date': '2019-12-31', 'symbol': 'NFLX', 'reportedCurrency': 'USD', 'cik': '0001065280', 'fillingDate': '2020-01-29', 'acceptedDate': '2020-01-29 16:03:25', 'calendarYear': '2019', 'period': 'FY', 'cashAndCashEquivalents': 5018437000, 'shortTermInvestments': 0.0, 'cashAndShortTermInvestments': 5018437000, 'netR ...

# %%
twoYearBalanceStatement= balanceStatements[:5]
twoYearIncomeStatement= incomeStatements[:5]

# %%
date=[]
profitability=[]
assetTurnOver=[]
capitalStructure=[]
returnOnEquity=[]

for i in range (0,4):
  date.append(twoYearIncomeStatement[i]['date'])
  profitabilityValue=twoYearIncomeStatement[i]['netIncome']/twoYearIncomeStatement[i]['revenue']
  profitability.append(profitabilityValue)
  assetTurnOverValue=twoYearIncomeStatement[i]['revenue']/twoYearBalanceStatement[i]['totalAssets']
  assetTurnOver.append(assetTurnOverValue)
  capitalStructureValue=twoYearBalanceStatement[i]['totalAssets']/twoYearBalanceStatement[i]['totalStockholdersEquity']
  capitalStructure.append(capitalStructureValue)
  returnOnEquityValue=profitabilityValue*assetTurnOverValue*capitalStructureValue
  returnOnEquity.append(returnOnEquityValue)

  print(returnOnEquity)
# Out:
# [0.3228057255460954]
# [0.3228057255460954, 0.24955581623173106]
# [0.3228057255460954, 0.24955581623173106, 0.24622491990076173]
# [0.3228057255460954, 0.24955581623173106, 0.24622491990076173, 0.23120754605331603]

# %%
Dataframe= pd.DataFrame(columns=['date','profitability','assetTurnOver','capitalStructure','returnOnEquity'])
Dataframe['date']=date
Dataframe['profitability']=profitability
Dataframe['assetTurnOver']=assetTurnOver
Dataframe['capitalStructure']=capitalStructure
Dataframe['returnOnEquity']=returnOnEquity

print(Dataframe)
# Out:
#          date  profitability  assetTurnOver  capitalStructure  returnOnEquity
# 0  2021-12-31       0.172276       0.666100          2.813046        0.322806
# 1  2020-12-31       0.110473       0.636350          3.549888        0.249556
# 2  2019-12-31       0.092621       0.593260          4.481009        0.246225
# 3  2018-12-31       0.076688       0.608073          4.958115        0.231208

# %%
import matplotlib.pyplot as plt

Dataframe.plot(x='date', y='profitability', kind='line')
plt.show()

Dataframe.plot(x='date', y='returnOnEquity', kind='line')
plt.show()
