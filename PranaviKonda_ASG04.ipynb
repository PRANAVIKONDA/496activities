# %% [markdown]
# <a href="https://colab.research.google.com/github/PRANAVIKONDA/496activities/blob/main/PranaviKonda_ASG04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
df=pd.read_csv('/content/drive/MyDrive/data.csv')
df.index=df['Skill']
df=df.sort_values(by='Frequency', ascending=False)
df["cumulativePercentage"] = df["Frequency"].cumsum()/df["Frequency"].sum()*100
df["cumulativePercentage"] = df["cumulativePercentage"].apply(lambda x:round(x,3))
print(df)


fig, ax = plt.subplots()

ax.bar(df.index, df["Frequency"], color="C3")

ax.set_xticklabels(df['Skill'], rotation=90)

ax2 = ax.twinx()

ax2.plot(df.index, df["cumulativePercentage"],color="C0", marker="D",ms=7, label = df["cumulativePercentage"])
ax2.yaxis.set_major_formatter(PercentFormatter())

ax.tick_params(axis="y", colors="C10")
ax2.tick_params(axis="y", colors="C10")

for index, v in df.iterrows():
  label = round(v['cumulativePercentage'],1)
  plt.annotate(label, xy=(v['Skill'],v['cumulativePercentage']))
  
plt.show()
# Out:
#                                                                          Skill  \
# Skill
# Incident Handling and Response                  Incident Handling and Response
# Threat Hunting                                                  Threat Hunting
# Knowledge of operating systems and VMs  Knowledge of operating systems and VMs
# Security Audits and Risk Assessments      Security Audits and Risk Assessments
# Coding                                                                  Coding
# Ethical Hacking                                                Ethical Hacking
# Networking and Security administration  Networking and Security administration
# Data Analysis                                                    Data Analysis
# Data Protection                                                Data Protection
# Collaboration and Communication               Collaboration and Communication
# Physical Security                                            Physical Security
#
#                                                                               Description  \
# Skill
# Incident Handling and Response                 Handling incidents and IRP implementations
# Threat Hunting                                             Monitoring and dealing threats
# Knowledge of operating systems and VMs   Wide idea about various OS and Virtual Machines
# Security Audits and Risk Assessments        Assessing standards and hazard identification
# Coding                                                               Programming Skills
# Ethical Hacking                             To prevent cyberattacks and security breaches
# Networking and Security administration  Updating security infrastructure and monitorin...
# Data Analysis                                               Analysis of the recorded data
# Data Protection                                             Protecting the company's data
# Collaboration and Communication                         Teamwork and communication skills
# Physical Security                                           Protection of physical things
#
#                                         Frequency  cumulativePercentage
# Skill
# Incident Handling and Response                 30                15.385
# Threat Hunting                                 28                29.744
# Knowledge of operating systems and VMs         26                43.077
# Security Audits and Risk Assessments           25                55.897
# Coding                                         20                66.154
# Ethical Hacking                                18                75.385
# Networking and Security administration         12                81.538
# Data Analysis                                  10                86.667
# Data Protection                                10                91.795
# Collaboration and Communication                 8                95.897
# Physical Security                               8               100.000
